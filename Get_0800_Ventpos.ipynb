# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Status overview & Dataframe Preparation

# %%
Vent = pd.read_csv("/Users/xinyuyangren/Documents/TU:e_Year2/Thesis/Aramis_Data_Warehouse/06_10_HourlyIndoor.csv")

#for 5,7,8,9 to rename br1 to br3

#Behav.rename(columns={'t_br1':'t_br3','rh_br1':'rh_br3','co2_br1':'co2_br3','con_br1':'con_br3','wc_br1':'wc_br3'}, inplace=True)

# %%
Vent1 = Vent[['date_trunc','8set_point_ventilation_unit']]

# %%
Vent1.describe()
# Out:
#        8set_point_ventilation_unit
# count                 17902.000000
# mean                      1.707686
# std                       0.563261
# min                       1.000000
# 25%                       1.000000
# 50%                       2.000000
# 75%                       2.000000
# max                       3.000000

# %%
Vent1.columns = ['date_trunc','set_point_ventilation_unit']

# %%
Vent1
# Out:
#                 date_trunc  set_point_ventilation_unit
# 0      2012-12-12 15:00:00                           2
# 1      2012-12-12 16:00:00                           2
# 2      2012-12-12 17:00:00                           2
# 3      2012-12-12 18:00:00                           2
# 4      2012-12-12 19:00:00                           2
# 5      2012-12-12 20:00:00                           2
# 6      2012-12-12 21:00:00                           2
# 7      2012-12-12 22:00:00                           2
# 8      2012-12-12 23:00:00                           2
# 9      2012-12-13 00:00:00                           2
# 10     2012-12-13 01:00:00                           2
# 11     2012-12-13 02:00:00                           2
# 12     2012-12-13 03:00:00                           1
# 13     2012-12-13 04:00:00                           1
# 14     2012-12-13 05:00:00                           1
# 15     2012-12-13 06:00:00                           2
# ...
