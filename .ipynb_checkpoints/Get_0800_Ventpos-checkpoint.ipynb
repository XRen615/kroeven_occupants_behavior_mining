# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# /Users/xinyuyangren/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# Status overview & Dataframe Preparation

# %%
Vent = pd.read_csv("/Users/xinyuyangren/Documents/TU:e_Year2/Thesis"
                    "/Aramis_Data_Warehouse/Behavior_Study/0800_Behav.csv")

#for 5,7,8,9 to rename br1 to br3

#Behav.rename(columns={'t_br1':'t_br3','rh_br1':'rh_br3','co2_br1':'co2_br3','con_br1':'con_br3','wc_br1':'wc_br3'}, inplace=True)

# %%
Vent1 = Vent[['dt','pulse_channel_ventilation_unit']]

# %%
Vent1
# Out:
#                          dt  pulse_channel_ventilation_unit
# 0       2013-01-01 00:02:35                               5
# 1       2013-01-01 00:05:35                               5
# 2       2013-01-01 00:08:35                               4
# 3       2013-01-01 00:11:35                               5
# 4       2013-01-01 00:14:35                               5
# 5       2013-01-01 00:17:35                               5
# 6       2013-01-01 00:20:35                               5
# 7       2013-01-01 00:23:35                               4
# 8       2013-01-01 00:26:35                               5
# 9       2013-01-01 00:29:35                               5
# 10      2013-01-01 00:32:35                               5
# 11      2013-01-01 00:35:35                               4
# 12      2013-01-01 00:38:35                               5
# 13      2013-01-01 00:41:35                               5
# 14      2013-01-01 00:44:35                               5
# ...

# %%
def remap(x):
    
    if x < 4:
        x = 1
    elif 4< x < 6:
        x = 2
    else:
        x = 3
    return x

pos = Vent1['pulse_channel_ventilation_unit'].apply(remap)
Vent1['pulse_channel_ventilation_unit'] = pos
